# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /Users/alejandrobuiles/.pyenv/versions/3.11.4/lib/python3.11/site-packages (0.2.44)
# Requirement already satisfied: pandas>=1.3.0 in /Users/alejandrobuiles/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in /Users/alejandrobuiles/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from yfinance) (2.1.1)
# Requirement already satisfied: requests>=2.31 in /Users/alejandrobuiles/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/alejandrobuiles/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /Users/alejandrobuiles/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/alejandrobuiles/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /Users/alejandrobuiles/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/alejandrobuiles/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in /Users/alejandrobuiles/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/alejandrobuiles/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /Users/alejandrobuiles/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/alejandrobuiles/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in /Users/alejandrobuiles/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /Users/alejandrobuiles/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/alejandrobuiles/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/alejandrobuiles/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/alejandrobuiles/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/alejandrobuiles/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/alejandrobuiles/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/alejandrobuiles/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2024.8.30)

# %%
import yfinance as yf
import pandas as pd

# %% [markdown]
# # Stock Data

# %% [markdown]
# **Stocks:** $ONCO, $CNEY, $TNXP, $APLD, $KTTA
#
# **Export data to `.csv`**

# %%
tickers = ["ONCO", "CNEY", "TNXP", "APLD", "KTTA"]
start_date = "2023-10-01"  
end_date = "2024-09-26"

# %%
data = {}

for ticker in tickers:
    stock_data = yf.Ticker(ticker).history(start=start_date, end=end_date)
    
    stock_data = stock_data[['Close', 'Volume']]
    stock_data.columns = [f'{ticker}_Close', f'{ticker}_Volume']  # Rename columns
    data[ticker] = stock_data

combined_data = pd.concat(data.values(), axis=1, join='inner')

# %%
combined_data.to_csv("../data/combined_stock_data.csv")

print(combined_data.head())
# Out:
#                            ONCO_Close  ONCO_Volume  CNEY_Close  CNEY_Volume  \
# Date
# 2023-10-02 00:00:00-04:00   20.719999         1098        3.57         8450
# 2023-10-03 00:00:00-04:00   19.719999         1805        3.39        26667
# 2023-10-04 00:00:00-04:00   17.240000          938        3.45        68543
# 2023-10-05 00:00:00-04:00   17.280001          755        3.63        44113
# 2023-10-06 00:00:00-04:00   17.200001         1453        3.60        19830
#
#                            TNXP_Close  TNXP_Volume  APLD_Close  APLD_Volume  \
# Date
# 2023-10-02 00:00:00-04:00   17.280001        11594       6.130      3041100
# 2023-10-03 00:00:00-04:00   16.959999         9038       5.380      4787800
# 2023-10-04 00:00:00-04:00   18.240000        18309       5.475      2217300
# 2023-10-05 00:00:00-04:00   18.879999        26206       5.200      3611100
# 2023-10-06 00:00:00-04:00   17.920000         6825       5.170      5334100
#
#                            KTTA_Close  KTTA_Volume
# Date
# 2023-10-02 00:00:00-04:00        9.50          665
# 2023-10-03 00:00:00-04:00        8.80         2375
# 2023-10-04 00:00:00-04:00        8.06         2240
# 2023-10-05 00:00:00-04:00        8.48         1700
# 2023-10-06 00:00:00-04:00        8.06          490

# %% [markdown]
# ### ONCO

# %% [markdown]
# **Sector:** Biotechnology
#
# **Industry:** Healthcare
#
# **Website:** https://onconetix.gcs-web.com

# %%
onco = yf.Ticker("ONCO")

# get all stock info
onco.info
# Out:
# {'address1': '201 East Fifth Street',
#  'address2': 'Suite 1900',
#  'city': 'Cincinnati',
#  'state': 'OH',
#  'zip': '45202',
#  'country': 'United States',
#  'phone': '513 620 4101',
#  'website': 'https://onconetix.gcs-web.com',
#  'industry': 'Biotechnology',
#  'industryKey': 'biotechnology',
#  'industryDisp': 'Biotechnology',
#  'sector': 'Healthcare',
#  'sectorKey': 'healthcare',
#  'sectorDisp': 'Healthcare',
#  'longBusinessSummary': "Onconetix, Inc., a biotechnology company, focuses on the research, development, and commercialization of solutions for men's health and oncology. It offers Entadfi, an FDA-approved, once daily pill that combines finasteride and tadalafil for the treatment of benign prostatic hyperplasia; and Proclarix, an in vitro protein-based blood diagnostic test for prostate cancer. The company was formerly known as Blue Water Biotech, Inc. and changed its name to Onconetix, Inc. in December 2023. Onconetix, Inc. was incorporated in 2018 and is headquartered in Cincinnati, Ohio.",
#  'fullTimeEmployees': 12,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Dr. Ralph  Schiess Ph.D.',
#    'age': 44,
#    'title': 'Interim CEO & Chief Science Officer',
#    'yearBorn': 1979,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Karina M. Fedasz',
#    'age': 50,
#    'title': 'Interim Chief Financial Officer',
#    'yearBorn': 1973,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Brian  Price Ph.D.',
#    'title': 'Head of Technology Strategy',
#    'fiscalYear': 2020,
#    'totalPay': 126479,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Frank A. Jaeger M.A., M.B.A.',
#    'age': 53,
#    'title': 'Senior VP of Marketing & Business Development',
#    'yearBorn': 1970,
#    'fiscalYear': 2020,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Andrew D. Skibo Ph.D.',
#    'title': 'Global Head of Biologics Operations',
#    'fiscalYear': 2020,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Theodore Scott Yoho',
#    'title': 'Head of Business Development',
#    'fiscalYear': 2020,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Ali I. Fattom Ph.D.',
#    'title': 'Head of Science & Discovery',
#    'fiscalYear': 2020,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Jay  Newmark M.B.A., M.D.',
#    'title': 'Chief Medical Officer',
#    'fiscalYear': 2020,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Christian  Bruhlmann',
#    'age': 46,
#    'title': 'Chief Strategy Officer & GM of Europe',
#    'yearBorn': 1977,
#    'fiscalYear': 2020,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Donald L. Very Jr., Ph.D.',
#    'title': 'Senior VP of Commercial Research & Development',
#    'fiscalYear': 2020,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'compensationAsOfEpochDate': 1609372800,
#  'maxAge': 86400,
#  'priceHint': 4,
#  'previousClose': 4.5,
#  'open': 4.42,
#  'dayLow': 4.3589,
#  'dayHigh': 4.8,
#  'regularMarketPreviousClose': 4.5,
#  'regularMarketOpen': 4.42,
#  'regularMarketDayLow': 4.3589,
#  'regularMarketDayHigh': 4.8,
#  'beta': 3.657,
#  'forwardPE': -5.5294113,
#  'volume': 63903,
#  'regularMarketVolume': 63903,
#  'averageVolume': 853058,
#  'averageVolume10days': 4035128,
#  'averageDailyVolume10Day': 4035128,
#  'bid': 4.71,
#  'ask': 4.76,
#  'bidSize': 100,
#  'askSize': 100,
#  'marketCap': 38982364,
#  'fiftyTwoWeekLow': 2.8,
#  'fiftyTwoWeekHigh': 21.4,
#  'priceToSalesTrailing12Months': 26.631918,
#  'fiftyDayAverage': 5.34066,
#  'twoHundredDayAverage': 6.306565,
#  'currency': 'USD',
#  'enterpriseValue': 24781328,
#  'floatShares': 313697,
#  'sharesOutstanding': 8294120,
#  'sharesShort': 5925,
#  'sharesShortPriorMonth': 27633,
#  'sharesShortPreviousMonthDate': 1723680000,
#  'dateShortInterest': 1726185600,
#  'sharesPercentSharesOut': 0.008,
#  'heldPercentInsiders': 0.2556,
#  'heldPercentInstitutions': 0.0126600005,
#  'shortRatio': 0.07,
#  'shortPercentOfFloat': 0.0081,
#  'impliedSharesOutstanding': 8478430,
#  'bookValue': -64.144,
#  'lastFiscalYearEnd': 1703980800,
#  'nextFiscalYearEnd': 1735603200,
#  'mostRecentQuarter': 1719705600,
#  'netIncomeToCommon': -53123056,
#  'trailingEps': -109.2,
#  'forwardEps': -0.85,
#  'lastSplitFactor': '1:40',
#  'lastSplitDate': 1727136000,
#  'enterpriseToRevenue': 16.93,
#  'enterpriseToEbitda': -1.636,
#  '52WeekChange': -0.7383721,
#  'SandP52WeekChange': 0.32295227,
#  'exchange': 'NCM',
#  'quoteType': 'EQUITY',
#  'symbol': 'ONCO',
#  'underlyingSymbol': 'ONCO',
#  'shortName': 'Onconetix, Inc.',
#  'longName': 'Onconetix, Inc.',
#  'firstTradeDateEpochUtc': 1645194600,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EDT',
#  'uuid': '32a5d7e9-d675-3883-aeca-199596981307',
#  'messageBoardId': 'finmb_600261365',
#  'gmtOffSetMilliseconds': -14400000,
#  'currentPrice': 4.7,
#  'recommendationMean': 3.0,
#  'recommendationKey': 'hold',
#  'totalCash': 930541,
#  'totalCashPerShare': 1.249,
#  'ebitda': -15146995,
#  'totalDebt': 15278488,
#  'quickRatio': 0.056,
#  'currentRatio': 0.099,
#  'totalRevenue': 1463746,
#  'revenuePerShare': 2.892,
#  'returnOnAssets': -0.21851999,
#  'freeCashflow': -6060771,
#  'operatingCashflow': -15783840,
#  'grossMargins': -0.57213,
#  'operatingMargins': -3.00331,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': None}

# %%
# ensure data is up-to-date
onco_stock_data = yf.download("ONCO", period="1d")

print(onco_stock_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
#             Open  High     Low  Close  Adj Close  Volume
# Date
# 2024-10-04  4.42   4.8  4.3589    4.7        4.7   63903

# %% [markdown]
# ### CNEY

# %% [markdown]
# **Sector:** Basic Materials
#
# **Industry:** Specialty Chemicals
#
# **Website:** https://www.cneny.com

# %%
cney = yf.Ticker("CNEY")

# get all stock info
cney.info
# Out:
# {'address1': 'Building 2-B',
#  'address2': 'Room 206 No. 268 Shiniu Road Liandu District',
#  'city': 'Lishui',
#  'country': 'China',
#  'phone': '86 571 8755 5823',
#  'website': 'https://www.cneny.com',
#  'industry': 'Specialty Chemicals',
#  'industryKey': 'specialty-chemicals',
#  'industryDisp': 'Specialty Chemicals',
#  'sector': 'Basic Materials',
#  'sectorKey': 'basic-materials',
#  'sectorDisp': 'Basic Materials',
#  'longBusinessSummary': "CN Energy Group. Inc., through its subsidiaries, engages in the manufacture and supply of wood-based activated carbon primarily in China. The company's activated carbon is used in pharmaceutical manufacturing, industrial manufacturing, water purification, environmental protection, and food and beverage production. It also engages in the generation and supply of biomass electricity; production of steam for heating; sale of minerals, stone, metal materials, construction materials, wood, chemical materials and products, rubber products, and paper products; management and conversion of forest and natural ecosystem; and forest acquisition, rights transfer, and nurturing, and timber harvesting and processing activities. The company was incorporated in 2018 and is based in Lishui, China.",
#  'fullTimeEmployees': 30,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Ms. Xinyang  Wang',
#    'age': 25,
#    'title': 'Chairwoman of the Board & Secretary of the Board',
#    'yearBorn': 1998,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Wenhua  Liu',
#    'age': 54,
#    'title': 'Interim CEO & Director',
#    'yearBorn': 1969,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Jinwu  Huang',
#    'age': 49,
#    'title': 'Chief Financial Officer',
#    'yearBorn': 1974,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'maxAge': 86400,
#  'priceHint': 4,
#  'previousClose': 0.7622,
#  'open': 0.7527,
#  'dayLow': 0.72,
#  'dayHigh': 0.7724,
#  'regularMarketPreviousClose': 0.7622,
#  'regularMarketOpen': 0.7527,
#  'regularMarketDayLow': 0.72,
#  'regularMarketDayHigh': 0.7724,
#  'beta': 0.789,
#  'volume': 590753,
#  'regularMarketVolume': 590753,
#  'averageVolume': 12216989,
#  'averageVolume10days': 36643280,
#  'averageDailyVolume10Day': 36643280,
#  'ask': 0.749,
#  'askSize': 300,
#  'marketCap': 6020126,
#  'fiftyTwoWeekLow': 0.255,
#  'fiftyTwoWeekHigh': 4.05,
#  'priceToSalesTrailing12Months': 0.09051545,
#  'fiftyDayAverage': 0.4178,
#  'twoHundredDayAverage': 0.889795,
#  'currency': 'USD',
#  'enterpriseValue': 8748136,
#  'profitMargins': -0.06631,
#  'floatShares': 2779441,
#  'sharesOutstanding': 2531670,
#  'sharesShort': 705180,
#  'sharesShortPriorMonth': 37759,
#  'sharesShortPreviousMonthDate': 1723680000,
#  'dateShortInterest': 1726185600,
#  'sharesPercentSharesOut': 0.26790002,
#  'heldPercentInsiders': 0.09059,
#  'heldPercentInstitutions': 0.03904,
#  'shortRatio': 0.04,
#  'shortPercentOfFloat': 0.2787,
#  'impliedSharesOutstanding': 3020970,
#  'bookValue': 32.355,
#  'priceToBook': 0.022722917,
#  'lastFiscalYearEnd': 1696032000,
#  'nextFiscalYearEnd': 1727654400,
#  'mostRecentQuarter': 1711843200,
#  'netIncomeToCommon': -4409929,
#  'trailingEps': -4.67,
#  'lastSplitFactor': '1:30',
#  'lastSplitDate': 1705622400,
#  'enterpriseToRevenue': 0.132,
#  'enterpriseToEbitda': -4.635,
#  '52WeekChange': -0.7888889,
#  'SandP52WeekChange': 0.32295227,
#  'exchange': 'NCM',
#  'quoteType': 'EQUITY',
#  'symbol': 'CNEY',
#  'underlyingSymbol': 'CNEY',
#  'shortName': 'CN Energy Group Inc.',
#  'longName': 'CN Energy Group. Inc.',
#  'firstTradeDateEpochUtc': 1612535400,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EDT',
#  'uuid': '629cc354-c7c2-381a-8a16-31fbb40d944e',
#  'messageBoardId': 'finmb_653860224',
#  'gmtOffSetMilliseconds': -14400000,
#  'currentPrice': 0.7352,
#  'recommendationKey': 'none',
#  'totalCash': 126416,
#  'totalCashPerShare': 0.04,
#  'ebitda': -1887426,
#  'totalDebt': 6459360,
#  'quickRatio': 2.162,
#  'currentRatio': 4.403,
#  'totalRevenue': 66509376,
#  'debtToEquity': 6.282,
#  'revenuePerShare': 33.941,
#  'returnOnAssets': -0.0222,
#  'returnOnEquity': -0.0417,
#  'freeCashflow': -535976,
#  'operatingCashflow': -1458050,
#  'revenueGrowth': 0.38,
#  'grossMargins': -0.00211,
#  'ebitdaMargins': -0.028380001,
#  'operatingMargins': -0.087019995,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': None}

# %%
# ensure data is up-to-date
cney_stock_data = yf.download("CNEY", period="1d")

print(cney_stock_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
#               Open    High   Low   Close  Adj Close  Volume
# Date
# 2024-10-04  0.7527  0.7724  0.72  0.7352     0.7352  590753

# %% [markdown]
# ### TNXP

# %% [markdown]
# **Sector:** Biotechnology
#
# **Industry:** Healthcare
#
# **Website:** https://www.tonixpharma.com

# %%
tnxp = yf.Ticker("TNXP")
# get all stock info
tnxp.info
# Out:
# {'address1': '26 Main Street',
#  'address2': 'Suite 101',
#  'city': 'Chatham',
#  'state': 'NJ',
#  'zip': '07928',
#  'country': 'United States',
#  'phone': '862 799 8599',
#  'fax': '862 904 8163',
#  'website': 'https://www.tonixpharma.com',
#  'industry': 'Biotechnology',
#  'industryKey': 'biotechnology',
#  'industryDisp': 'Biotechnology',
#  'sector': 'Healthcare',
#  'sectorKey': 'healthcare',
#  'sectorDisp': 'Healthcare',
#  'longBusinessSummary': "Tonix Pharmaceuticals Holding Corp., a biopharmaceutical company, focuses on developing, discovering, commercializing, and licensing therapeutics to treat and prevent human disease and alleviate suffering. It markets Zembrace SymTouch and Tosymra for the treatment of acute migraine with or without aura in adults. Its portfolio focuses on central nervous system disorders, as well as rare disease, immunology, and infectious disease product candidates. The company's priority is to submit a New Drug Application (NDA) to the FDA for TNX-102 SL (cyclobenzaprine HCl sublingual tablet), which has completed two positive Phase 3 studies for the management of fibromyalgia. TNX-102 SL is also being developed to treat fibromyalgia-type Long COVID, a chronic post-acute COVID-19 condition. Its TNX-1300 (cocaine esterase) is a biologic designed to treat cocaine intoxication and has been granted breakthrough therapy designation by the FDA. The company's rare disease development portfolio comprises TNX-2900, an intranasal potentiated oxytocin for the treatment of Prader-Willi syndrome (PWS). Its immunology portfolio includes TNX-1500, which is a biologic to address organ transplant rejection and autoimmune diseases. The company's infectious disease pipeline includes TNX-801, a vaccine in development to prevent smallpox and mpox. TNX-801 also serves as the live virus vaccine platform or recombinant pox vaccine platform for other infectious diseases, including TNX-1800 and TNX-1850, in development as a vaccine to protect against COVID-19. Its infectious disease development portfolio also comprises TNX-3900, and TNX-4200 are orally available CD45 antagonists in preclinical development. Tonix Pharmaceuticals Holding Corp. has collaboration agreement with Bilthoven Biologicals to advance TNX-801 mpox vaccine candidate. The company was founded in 2007 and is headquartered in Chatham, New Jersey.",
#  'fullTimeEmployees': 103,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Dr. Seth  Lederman M.D.',
#    'age': 65,
#    'title': 'Co-Founder, President, CEO & Chairman',
#    'yearBorn': 1958,
#    'fiscalYear': 2023,
#    'totalPay': 675000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Bradley  Saenger CPA',
#    'age': 49,
#    'title': 'CFO & Treasurer',
#    'yearBorn': 1974,
#    'fiscalYear': 2023,
#    'totalPay': 640770,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mrs. Jessica Edgar Morris',
#    'title': 'Chief Operating Officer',
#    'fiscalYear': 2023,
#    'totalPay': 654550,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Gregory M. Sullivan M.D.',
#    'age': 57,
#    'title': 'Chief Medical Officer & Secretary',
#    'yearBorn': 1966,
#    'fiscalYear': 2023,
#    'totalPay': 661440,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Herbert W. Harris M.D., Ph.D.',
#    'title': 'Executive Vice President of Translational Medicine',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Siobhan  Fogarty B.Sc., M.Sc.',
#    'title': 'Executive Vice President of Product Development',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Darryl  Rideout Ph.D.',
#    'title': 'Executive Vice President of Experimental Chemistry',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Sina  Bavari Ph.D.',
#    'title': 'Executive Vice President of Infectious Disease Research & Development',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Zeil  Rosenberg M.D., M.P.H.',
#    'title': 'Executive Vice President of Medical',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Thomas  Englese',
#    'age': 49,
#    'title': 'Executive Vice President of Commercial Operations',
#    'yearBorn': 1974,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'compensationAsOfEpochDate': 1703980800,
#  'maxAge': 86400,
#  'priceHint': 4,
#  'previousClose': 0.126,
#  'open': 0.1264,
#  'dayLow': 0.123,
#  'dayHigh': 0.1458,
#  'regularMarketPreviousClose': 0.126,
#  'regularMarketOpen': 0.1264,
#  'regularMarketDayLow': 0.123,
#  'regularMarketDayHigh': 0.1458,
#  'beta': 2.087,
#  'forwardPE': -0.0045616305,
#  'volume': 19882964,
#  'regularMarketVolume': 19882964,
#  'averageVolume': 25264501,
#  'averageVolume10days': 32811450,
#  'averageDailyVolume10Day': 32811450,
#  'bid': 0.1392,
#  'ask': 0.1407,
#  'bidSize': 3400,
#  'askSize': 1800,
#  'marketCap': 19738168,
#  'fiftyTwoWeekLow': 0.12,
#  'fiftyTwoWeekHigh': 22.08,
#  'priceToSalesTrailing12Months': 1.5843769,
#  'fiftyDayAverage': 0.3058,
#  'twoHundredDayAverage': 5.49435,
#  'currency': 'USD',
#  'enterpriseValue': 7874524,
#  'floatShares': 22003939,
#  'sharesOutstanding': 139987008,
#  'sharesShort': 467194,
#  'sharesShortPriorMonth': 1303364,
#  'sharesShortPreviousMonthDate': 1723680000,
#  'dateShortInterest': 1726185600,
#  'sharesPercentSharesOut': 0.0037,
#  'heldPercentInsiders': 0.00211,
#  'heldPercentInstitutions': 0.0028600001,
#  'shortRatio': 0.01,
#  'shortPercentOfFloat': 0.0037,
#  'impliedSharesOutstanding': 145044000,
#  'bookValue': 4.282,
#  'priceToBook': 0.032928538,
#  'lastFiscalYearEnd': 1703980800,
#  'nextFiscalYearEnd': 1735603200,
#  'mostRecentQuarter': 1719705600,
#  'netIncomeToCommon': -149012000,
#  'trailingEps': -139.08,
#  'forwardEps': -30.91,
#  'lastSplitFactor': '1:32',
#  'lastSplitDate': 1717977600,
#  'enterpriseToRevenue': 0.632,
#  'enterpriseToEbitda': -0.087,
#  '52WeekChange': -0.9927455,
#  'SandP52WeekChange': 0.32295227,
#  'exchange': 'NCM',
#  'quoteType': 'EQUITY',
#  'symbol': 'TNXP',
#  'underlyingSymbol': 'TNXP',
#  'shortName': 'Tonix Pharmaceuticals Holding C',
#  'longName': 'Tonix Pharmaceuticals Holding Corp.',
#  'firstTradeDateEpochUtc': 1336656600,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EDT',
#  'uuid': '99a890b3-8f0b-36fb-b33b-06470554e372',
#  'messageBoardId': 'finmb_112008811',
#  'gmtOffSetMilliseconds': -14400000,
#  'currentPrice': 0.141,
#  'targetHighPrice': 48.0,
#  'targetLowPrice': 4.0,
#  'targetMeanPrice': 21.0,
#  'targetMedianPrice': 11.0,
#  'recommendationMean': 2.0,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 3,
#  'totalCash': 4156000,
#  'totalCashPerShare': 0.189,
#  'ebitda': -90770000,
#  'totalDebt': 9258000,
#  'quickRatio': 0.34,
#  'currentRatio': 1.147,
#  'totalRevenue': 12458000,
#  'debtToEquity': 21.989,
#  'revenuePerShare': 6.352,
#  'returnOnAssets': -0.51722,
#  'returnOnEquity': -1.6324201,
#  'freeCashflow': -44012248,
#  'operatingCashflow': -73219000,
#  'grossMargins': 0.21593,
#  'operatingMargins': -8.31476,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': None}

# %%
# ensure data is up-to-date
tnxp_stock_data = yf.download("TNXP", period="1d")

print(tnxp_stock_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
#               Open    High    Low  Close  Adj Close    Volume
# Date
# 2024-10-04  0.1264  0.1458  0.123  0.141      0.141  19882964

# %% [markdown]
# ### APLD

# %% [markdown]
# **Sector:** Technology
#
# **Industry:** Information Technology Services
#
# **Website:** https://applieddigital.com

# %%
apld = yf.Ticker("APLD")
# get all stock info
apld.info
# Out:
# {'address1': '3811 Turtle Creek Boulevard',
#  'address2': 'Suite 2100',
#  'city': 'Dallas',
#  'state': 'TX',
#  'zip': '75219',
#  'country': 'United States',
#  'phone': '214 427 1704',
#  'website': 'https://applieddigital.com',
#  'industry': 'Information Technology Services',
#  'industryKey': 'information-technology-services',
#  'industryDisp': 'Information Technology Services',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'Applied Digital Corporation designs, develops, and operates digital infrastructure solutions and cloud services high-performance computing (HPC) and artificial intelligence industries in North America. It operates through three segments: Data Center Hosting Business, Cloud Services Business, and HPC Hosting Business. The company offers infrastructure services to crypto mining customers; and GPU computing solutions for critical workloads related to AI, machine learning, and other HPC tasks. It also engages in the designing, constructing, and managing of data centers to support HPC applications. The company was formerly known as Applied Blockchain, Inc. and changed its name to Applied Digital Corporation in November 2022. Applied Digital Corporation is based in Dallas, Texas.',
#  'fullTimeEmployees': 150,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Wesley  Cummins',
#    'age': 45,
#    'title': 'Chairman, CEO, President, Secretary & Treasurer',
#    'yearBorn': 1978,
#    'fiscalYear': 2024,
#    'totalPay': 2895169,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. David  Rench',
#    'age': 45,
#    'title': 'Chief Financial Officer',
#    'yearBorn': 1978,
#    'fiscalYear': 2024,
#    'totalPay': 1717990,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Michael  Maniscalco',
#    'age': 43,
#    'title': 'Chief Technology Officer',
#    'yearBorn': 1980,
#    'fiscalYear': 2024,
#    'totalPay': 1175573,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Kate  Reed',
#    'age': 37,
#    'title': 'Chief Growth Officer & Director',
#    'yearBorn': 1986,
#    'fiscalYear': 2024,
#    'totalPay': 20000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Nick  Phillips',
#    'title': 'Executive Vice President of Public Affairs & Real Estate Acquisitions',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. LaTascha  Durden',
#    'title': 'Director of Human Resources',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Roland  Davidson',
#    'title': 'Executive Vice President of Engineering',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Brad  Barton',
#    'title': 'EVP of Real Estate Development',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Todd  Gale',
#    'title': 'Chief Development Officer',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Chris  Jackson',
#    'title': 'Senior Vice President of Operations',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 10,
#  'boardRisk': 8,
#  'compensationRisk': 10,
#  'shareHolderRightsRisk': 4,
#  'overallRisk': 10,
#  'governanceEpochDate': 1727740800,
#  'compensationAsOfEpochDate': 1735603200,
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 8.04,
#  'open': 8.05,
#  'dayLow': 7.35,
#  'dayHigh': 8.26,
#  'regularMarketPreviousClose': 8.04,
#  'regularMarketOpen': 8.05,
#  'regularMarketDayLow': 7.35,
#  'regularMarketDayHigh': 8.26,
#  'beta': 4.425,
#  'forwardPE': -5.223427,
#  'volume': 10943795,
#  'regularMarketVolume': 10943795,
#  'averageVolume': 10999387,
#  'averageVolume10days': 14099090,
#  'averageDailyVolume10Day': 14099090,
#  'bid': 7.42,
#  'ask': 7.51,
#  'bidSize': 13400,
#  'askSize': 10500,
#  'marketCap': 1602290048,
#  'fiftyTwoWeekLow': 2.36,
#  'fiftyTwoWeekHigh': 8.785,
#  'priceToSalesTrailing12Months': 9.677125,
#  'fiftyDayAverage': 5.2045,
#  'twoHundredDayAverage': 4.8928,
#  'currency': 'USD',
#  'enterpriseValue': 1690270464,
#  'profitMargins': -0.90155,
#  'floatShares': 131498721,
#  'sharesOutstanding': 214511008,
#  'sharesShort': 24092034,
#  'sharesShortPriorMonth': 18224846,
#  'sharesShortPreviousMonthDate': 1723680000,
#  'dateShortInterest': 1726185600,
#  'sharesPercentSharesOut': 0.11229999,
#  'heldPercentInsiders': 0.18621,
#  'heldPercentInstitutions': 0.40155998,
#  'shortRatio': 1.51,
#  'shortPercentOfFloat': 0.1273,
#  'impliedSharesOutstanding': 214511008,
#  'bookValue': 0.898,
#  'priceToBook': 8.317928,
#  'lastFiscalYearEnd': 1717113600,
#  'nextFiscalYearEnd': 1748649600,
#  'mostRecentQuarter': 1717113600,
#  'netIncomeToCommon': -149274000,
#  'trailingEps': -1.31,
#  'forwardEps': -1.43,
#  'lastSplitFactor': '1:6',
#  'lastSplitDate': 1649808000,
#  'enterpriseToRevenue': 10.208,
#  'enterpriseToEbitda': -905.826,
#  '52WeekChange': 0.5551257,
#  'SandP52WeekChange': 0.32295227,
#  'exchange': 'NMS',
#  'quoteType': 'EQUITY',
#  'symbol': 'APLD',
#  'underlyingSymbol': 'APLD',
#  'shortName': 'Applied Digital Corporation',
#  'longName': 'Applied Digital Corporation',
#  'firstTradeDateEpochUtc': 1649856600,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EDT',
#  'uuid': 'b6f3f33e-e6a3-3625-aba2-00d4d8143fb7',
#  'messageBoardId': 'finmb_3563673',
#  'gmtOffSetMilliseconds': -14400000,
#  'currentPrice': 7.4695,
#  'targetHighPrice': 12.0,
#  'targetLowPrice': 5.0,
#  'targetMeanPrice': 9.14,
#  'targetMedianPrice': 10.0,
#  'recommendationMean': 2.0,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 7,
#  'totalCash': 3339000,
#  'totalCashPerShare': 0.021,
#  'ebitda': -1866000,
#  'totalDebt': 427806016,
#  'quickRatio': 0.019,
#  'currentRatio': 0.078,
#  'totalRevenue': 165575008,
#  'debtToEquity': 342.711,
#  'revenuePerShare': 1.452,
#  'returnOnAssets': -0.09887999,
#  'returnOnEquity': -1.53896,
#  'freeCashflow': -14114250,
#  'operatingCashflow': 13794000,
#  'revenueGrowth': 0.983,
#  'grossMargins': 0.104090005,
#  'ebitdaMargins': -0.01127,
#  'operatingMargins': -0.85473,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': None}

# %%
# ensure data is up-to-date
apld_stock_data = yf.download("APLD", period="1d")

print(apld_stock_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
#             Open  High   Low   Close  Adj Close    Volume
# Date
# 2024-10-04  8.05  8.26  7.35  7.4695     7.4695  10943795

# %% [markdown]
# ### KTTA

# %% [markdown]
# **Sector:** Biotechnology
#
# **Industry:** Healthcare
#
# **Website:** https://www.pasithea.com

# %%
ktta = yf.Ticker("KTTA")
# get all stock info
ktta.info
# Out:
# {'address1': '1111 Lincoln Road',
#  'address2': 'Suite 500',
#  'city': 'Miami Beach',
#  'state': 'FL',
#  'zip': '33139',
#  'country': 'United States',
#  'phone': '702 514 4174',
#  'website': 'https://www.pasithea.com',
#  'industry': 'Biotechnology',
#  'industryKey': 'biotechnology',
#  'industryDisp': 'Biotechnology',
#  'sector': 'Healthcare',
#  'sectorKey': 'healthcare',
#  'sectorDisp': 'Healthcare',
#  'longBusinessSummary': 'Pasithea Therapeutics Corp., a biotechnology company, engages in discovery, research, and development of treatments for central nervous system disorders, RASopathies, and other diseases. Its lead product candidate PAS-004, a next-generation macrocyclic mitogen-activated protein kinase, or MEK inhibitor for use in the treatment of a range of RASopathies, including neurofibromatosis type 1 oncology indications. The company intends to develop PAS-003, to treat amyotrophic lateral sclerosis; and PAS-001, to treat schizophrenia. Pasithea Therapeutics Corp. was incorporated in 2020 and is headquartered in Miami Beach, Florida.',
#  'fullTimeEmployees': 8,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Dr. Lawrence  Steinman BA, M.D., Ph.D.',
#    'age': 75,
#    'title': 'Co-Founder, MD & Executive Chairman',
#    'yearBorn': 1948,
#    'fiscalYear': 2023,
#    'totalPay': 250000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Tiago Reis Marques M.D., Ph.D.',
#    'age': 46,
#    'title': 'CEO & Director',
#    'yearBorn': 1977,
#    'fiscalYear': 2023,
#    'totalPay': 480000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Daniel H. Schneiderman',
#    'age': 45,
#    'title': 'Chief Financial Officer',
#    'yearBorn': 1978,
#    'fiscalYear': 2023,
#    'totalPay': 345939,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Graeme  Currie Ph.D.',
#    'age': 56,
#    'title': 'Chief Development Officer',
#    'yearBorn': 1967,
#    'fiscalYear': 2023,
#    'totalPay': 346617,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Yassine  Bendiabdallah Ph.D.',
#    'age': 39,
#    'title': 'COO & Head of UK Clinics',
#    'yearBorn': 1984,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'compensationAsOfEpochDate': 1703980800,
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 5.19,
#  'open': 5.125,
#  'dayLow': 5.11,
#  'dayHigh': 5.45,
#  'regularMarketPreviousClose': 5.19,
#  'regularMarketOpen': 5.125,
#  'regularMarketDayLow': 5.11,
#  'regularMarketDayHigh': 5.45,
#  'beta': 0.77,
#  'forwardPE': -7.555493,
#  'volume': 17578,
#  'regularMarketVolume': 17578,
#  'averageVolume': 930332,
#  'averageVolume10days': 5855500,
#  'averageDailyVolume10Day': 5855500,
#  'bid': 5.36,
#  'ask': 5.45,
#  'bidSize': 100,
#  'askSize': 100,
#  'marketCap': 5600862,
#  'fiftyTwoWeekLow': 3.61,
#  'fiftyTwoWeekHigh': 17.4,
#  'fiftyDayAverage': 4.72476,
#  'twoHundredDayAverage': 6.211365,
#  'currency': 'USD',
#  'enterpriseValue': -2502849,
#  'floatShares': 802460,
#  'sharesOutstanding': 1044080,
#  'sharesShort': 419,
#  'sharesShortPriorMonth': 7847,
#  'sharesShortPreviousMonthDate': 1723680000,
#  'dateShortInterest': 1726185600,
#  'sharesPercentSharesOut': 0.0004,
#  'heldPercentInsiders': 0.23142,
#  'heldPercentInstitutions': 0.02873,
#  'shortRatio': 0.03,
#  'shortPercentOfFloat': 0.0005,
#  'impliedSharesOutstanding': 1044080,
#  'bookValue': 15.492,
#  'priceToBook': 0.34626904,
#  'lastFiscalYearEnd': 1703980800,
#  'nextFiscalYearEnd': 1735603200,
#  'mostRecentQuarter': 1719705600,
#  'netIncomeToCommon': -16370943,
#  'trailingEps': -14.79,
#  'forwardEps': -0.71,
#  'lastSplitFactor': '1:20',
#  'lastSplitDate': 1704153600,
#  'enterpriseToEbitda': 0.154,
#  '52WeekChange': -0.35062033,
#  'SandP52WeekChange': 0.32295227,
#  'exchange': 'NCM',
#  'quoteType': 'EQUITY',
#  'symbol': 'KTTA',
#  'underlyingSymbol': 'KTTA',
#  'shortName': 'Pasithea Therapeutics Corp.',
#  'longName': 'Pasithea Therapeutics Corp.',
#  'firstTradeDateEpochUtc': 1631712600,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EDT',
#  'uuid': 'f19ed9f9-de4f-3b85-b823-68e1246ae624',
#  'messageBoardId': 'finmb_702706441',
#  'gmtOffSetMilliseconds': -14400000,
#  'currentPrice': 5.3644,
#  'recommendationMean': 2.0,
#  'recommendationKey': 'buy',
#  'totalCash': 7967569,
#  'totalCashPerShare': 7.631,
#  'ebitda': -16274925,
#  'quickRatio': 5.712,
#  'currentRatio': 6.196,
#  'returnOnAssets': -0.37903,
#  'returnOnEquity': -0.6325,
#  'freeCashflow': -9018887,
#  'operatingCashflow': -14920285,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': None}

# %%
# ensure data is up-to-date
ktta_stock_data = yf.download("KTTA", period="1d")
print(ktta_stock_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
#              Open  High   Low   Close  Adj Close  Volume
# Date
# 2024-10-04  5.125  5.45  5.11  5.3644     5.3644   17578

# %% [markdown]
# # Sentiment Data

# %% [markdown]
# #### Alpha Vantage Market News & Sentiment

# %%
import requests
import csv
from textblob import TextBlob
from datetime import datetime

# API key and function for Alpha Vantage
api_key = 'H1EMSYRMNJUX1ASO'
function = 'NEWS_SENTIMENT'

# List of stock ticker symbols
tickers = ['ONCO', 'CNEY', 'TNXP', 'APLD', 'KTTA']

start_date = "2023-10-01" 
end_date = "2024-09-26"    

time_from = datetime.strptime(start_date, "%Y-%m-%d").strftime("%Y%m%dT0000")  # Starting from midnight
time_to = datetime.strptime(end_date, "%Y-%m-%d").strftime("%Y%m%dT2359")  # Ending at 23:59

def get_sentiment(text):
    blob = TextBlob(text)
    return blob.sentiment.polarity

for ticker in tickers:
    url = f'https://www.alphavantage.co/query?function={function}&tickers={ticker}&apikey={api_key}&time_from={time_from}&time_to={time_to}'

    response = requests.get(url)
    data = response.json()

    articles = data.get('feed', [])
    
    processed_articles = []
    
    for article in articles:
        title = article.get('title', 'N/A')
        summary = article.get('summary', '')  #
        time_published= article.get('time_published', 'N/A') 
        
        sentiment = get_sentiment(summary)
        
        processed_articles.append([title, summary, sentiment, time_published])
    
    filename = f'../data/unprocessed data/{ticker}_news_sentiment.csv'
    
    with open(filename, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        
        writer.writerow(['Title', 'Summary', 'Sentiment', 'Date Published'])
        
        writer.writerows(processed_articles)
    
    print(f'Sentiment data for {ticker} within date range saved to {filename}')
# Out:
# Sentiment data for ONCO within date range saved to ../data/ONCO_news_sentiment.csv
# Sentiment data for CNEY within date range saved to ../data/CNEY_news_sentiment.csv
# Sentiment data for TNXP within date range saved to ../data/TNXP_news_sentiment.csv
# Sentiment data for APLD within date range saved to ../data/APLD_news_sentiment.csv
# Sentiment data for KTTA within date range saved to ../data/KTTA_news_sentiment.csv
